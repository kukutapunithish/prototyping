# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gemini-2.5-flash-lite")
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# File ~\Personal Data\Projects\overall\prototyping\ai_learn\agents\lca-lc-foundations\.venv\Lib\site-packages\google\cloud\aiplatform\initializer.py:367, in _Config.project(self)
#     366 try:
# --> 367     self._set_project_as_env_var_or_google_auth_default()
#     368     project_id = self._project
#
# File ~\Personal Data\Projects\overall\prototyping\ai_learn\agents\lca-lc-foundations\.venv\Lib\site-packages\google\cloud\aiplatform\initializer.py:114, in _Config._set_project_as_env_var_or_google_auth_default(self)
#     113 else:
# --> 114     credentials, project = google.auth.default()
#     115     self._credentials = self._credentials or credentials
#
# File ~\Personal Data\Projects\overall\prototyping\ai_learn\agents\lca-lc-foundations\.venv\Lib\site-packages\google\auth\_default.py:752, in default(scopes, request, quota_project_id, default_scopes)
#     750         return credentials, effective_project_id
# --> 752 raise exceptions.DefaultCredentialsError(_CLOUD_SDK_MISSING_CREDENTIALS)
#
# DefaultCredentialsError: Your default credentials were not found. To set up Application Default Credentials, see https://cloud.google.com/docs/authentication/external/set-up-adc for more information.
#
# The above exception was the direct cause of the following exception:
#
# GoogleAuthError                           Traceback (most recent call last)
# Cell In[15], line 3
#       1 from langchain.chat_models import init_chat_model
# ----> 3 model = init_chat_model(model="gemini-2.5-flash-lite")
#
# File ~\Personal Data\Projects\overall\prototyping\ai_learn\agents\lca-lc-foundations\.venv\Lib\site-packages\langchain\chat_models\base.py:464, in init_chat_model(model, model_provider, configurable_fields, config_prefix, **kwargs)
#     456     warnings.warn(
#     457         f"{config_prefix=} has been set but no fields are configurable. Set "
#     458         f"`configurable_fields=(...)` to specify the model params that are "
#     459         f"configurable.",
#     460         stacklevel=2,
#     461     )
#     463 if not configurable_fields:
# --> 464     return _init_chat_model_helper(
#     465         cast("str", model),
#     466         model_provider=model_provider,
#     467         **kwargs,
#     468     )
#     469 if model:
#     470     kwargs["model"] = model
#
# File ~\Personal Data\Projects\overall\prototyping\ai_learn\agents\lca-lc-foundations\.venv\Lib\site-packages\langchain\chat_models\base.py:488, in _init_chat_model_helper(model, model_provider, **kwargs)
#     486 model, model_provider = _parse_model(model, model_provider)
#     487 creator_func = _get_chat_model_creator(model_provider)
# --> 488 return creator_func(model=model, **kwargs)
#
# File ~\Personal Data\Projects\overall\prototyping\ai_learn\agents\lca-lc-foundations\.venv\Lib\site-packages\langchain\chat_models\base.py:35, in _call(cls, **kwargs)
#      33 def _call(cls: type[BaseChatModel], **kwargs: Any) -> BaseChatModel:
#      34     # TODO: replace with operator.call when lower bounding to Python 3.11
# ---> 35     return cls(**kwargs)
#
# File ~\Personal Data\Projects\overall\prototyping\ai_learn\agents\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\_api\deprecation.py:237, in deprecated.<locals>.deprecate.<locals>.finalize.<locals>.warn_if_direct_instance(self, *args, **kwargs)
#     235     warned = True
#     236     emit_warning()
# --> 237 return wrapped(self, *args, **kwargs)
#
# File ~\Personal Data\Projects\overall\prototyping\ai_learn\agents\lca-lc-foundations\.venv\Lib\site-packages\langchain_google_vertexai\chat_models.py:1943, in ChatVertexAI.__init__(self, model_name, **kwargs)
#    1937         suggestion = (
#    1938             f" Did you mean: '{suggestions[0]}'?" if suggestions else ""
#    1939         )
#    1940         logger.warning(
#    1941             f"Unexpected argument '{arg}' provided to ChatVertexAI.{suggestion}"
#    1942         )
# -> 1943 super().__init__(**kwargs)
#
# File ~\Personal Data\Projects\overall\prototyping\ai_learn\agents\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\load\serializable.py:118, in Serializable.__init__(self, *args, **kwargs)
#     116 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     117     """"""  # noqa: D419  # Intentional blank docstring
# --> 118     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File ~\Personal Data\Projects\overall\prototyping\ai_learn\agents\lca-lc-foundations\.venv\Lib\site-packages\langchain_google_vertexai\_base.py:156, in _VertexAIBase.validate_project(self)
#     154         self.project = self.credentials.project_id
#     155     else:
# --> 156         self.project = initializer.global_config.project
#     157 return self
#
# File ~\Personal Data\Projects\overall\prototyping\ai_learn\agents\lca-lc-foundations\.venv\Lib\site-packages\google\cloud\aiplatform\initializer.py:370, in _Config.project(self)
#     368     project_id = self._project
#     369 except GoogleAuthError as exc:
# --> 370     raise GoogleAuthError(project_not_found_exception_str) from exc
#     372 if not project_id and not self.api_key:
#     373     raise ValueError(project_not_found_exception_str)
#
# GoogleAuthError: Unable to find your project. Please provide a project ID by:
# - Passing a constructor argument
# - Using vertexai.init()
# - Setting project using 'gcloud config set project my-project'
# - Setting a GCP environment variable
# - To create a Google Cloud project, please follow guidance at https://developers.google.com/workspace/guides/create-project

# %%
response = model.invoke("What's the capital of the Moon?")

response

# %%
print(response.content)

# %%
from pprint import pprint

pprint(response.response_metadata)

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gpt-5-nano",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-5")

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# That's a fun question! The Moon doesn't have a capital city in the way Earth does. It's a celestial body without any permanent human settlements or governments.
#
# So, the answer is: **The Moon has no capital.**

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent(model="claude-sonnet-4-5")

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='4f3799c9-618c-4bc4-bb83-5393c6a3b0db'),
#               AIMessage(content='That\'s a fun question! The Moon doesn\'t have a capital city. It\'s not a country or a populated planet with a government.\n\nHowever, if we were to imagine a "capital" based on human activity and significance, some might jokingly point to:\n\n*   **Tranquility Base:** This is where Neil Armstrong and Buzz Aldrin first landed in 1969, making it the site of humanity\'s first steps on the Moon. It\'s a historically very important spot!\n\nBut in reality, the Moon is a celestial body without any cities or political structures.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ed904-d8a1-7da1-ac05-3820a7a6179b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 124, 'total_tokens': 134, 'input_token_details': {'cache_read': 0}})]}

# %%
print(response['messages'][-1].content)
# Out:
# That's a fun question! The Moon doesn't have a capital city. It's not a country or a populated planet with a government.
#
# However, if we were to imagine a "capital" based on human activity and significance, some might jokingly point to:
#
# *   **Tranquility Base:** This is where Neil Armstrong and Buzz Aldrin first landed in 1969, making it the site of humanity's first steps on the Moon. It's a historically very important spot!
#
# But in reality, the Moon is a celestial body without any cities or political structures.

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='ff25372b-3e0e-461e-8d54-c34a1e13c180'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='50a03ea0-2388-4f7f-89a5-fa6d95c6553a', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='0fb643fd-7d1e-4d0f-9157-37bc16786aed'),
#               AIMessage(content="Luna City is a fictional city that is often depicted as the capital of the Moon in science fiction stories and popular culture. It's usually portrayed as a bustling metropolis, a hub of human activity and the center of lunar governance.\n\nHere's what you might find in a typical depiction of Luna City:\n\n*   **Location:** It's often imagined to be built within a large crater or a lava tube for protection from radiation and micrometeorites. Some stories place it on the surface, shielded by domes, while others prefer subterranean locations.\n*   **Architecture:** Expect futuristic designs, often with a focus on functionality and resource efficiency. Think sleek, modular buildings, transparent domes, and advanced life support systems.\n*   **Population:** Luna City would likely be home to a diverse population of scientists, engineers, miners, administrators, and families who have chosen to live on the Moon. It could be a melting pot of cultures and nationalities.\n*   **Economy:** Its economy would likely be driven by resource extraction (like helium-3 for fusion power), scientific research, space tourism, and manufacturing. It could also serve as a staging ground for further space exploration.\n*   **Governance:** As the capital, it would house the administrative and political centers for lunar society. This might include a lunar council, government offices, and perhaps even a representative assembly.\n*   **Infrastructure:** Advanced transportation systems, including magnetic levitation trains and personal transport pods, would be common. Power would likely come from solar, fusion, or geothermal sources.\n*   **Culture and Lifestyle:** Life in Luna City would be unique, shaped by the lunar environment. Residents might experience lower gravity, requiring adjustments to daily life. Entertainment and recreation would likely be adapted to the enclosed or low-gravity environment.\n*   **Challenges:** Despite its advanced nature, Luna City would likely face unique challenges, such as maintaining atmospheric pressure, dealing with dust, and ensuring the psychological well-being of its inhabitants in an isolated environment.\n\n**Where you'll find Luna City:**\n\nYou'll encounter Luna City in various forms across different fictional works:\n\n*   **Literature:** Many science fiction novels have featured lunar cities, from classic tales to contemporary epics.\n*   **Film and Television:** Movies and TV shows have brought Luna City to life visually, showcasing its grandeur and the lives of its inhabitants.\n*   **Video Games:** Interactive experiences often allow players to explore and interact with Luna City.\n\nIt's important to remember that **Luna City is a concept born from imagination**. While humans have landed on the Moon and plans for lunar bases are being developed, a fully established capital city like the one described in fiction does not yet exist. However, the idea of Luna City captures our aspirations for a future where humanity has a significant presence beyond Earth.", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ed906-24cf-7583-b78e-3c844b7ad09a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 29, 'output_tokens': 579, 'total_tokens': 608, 'input_token_details': {'cache_read': 0}})]}

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Luna City, the vibrant capital of the Moon, is a marvel of human ingenuity and a testament to our enduring spirit of exploration. Nestled within a vast, domed metropolis on the Sea of Tranquility, it gleams under the perpetual starlight of the cosmos. While fictional, Luna City is a rich concept brimming with possibilities. Here's a comprehensive look at what it might entail:
#
# ## Location and Architecture:
#
# *   **The Great Dome:** Luna City is protected by a colossal, transparent dome, engineered from advanced, radiation-shielding materials. This dome not only provides a breathable atmosphere and shields inhabitants from the harsh lunar environment but also offers breathtaking, unobstructed views of Earth and the starry expanse.
# *   **Underground Networks:** Beyond the dome, a sprawling network of underground tunnels and habitats extends deep into the lunar regolith. This provides additional living space, research facilities, and protection from micrometeorites and radiation.
# *   **Verticality and Integration:** Luna City is characterized by its verticality. Towers of sleek, minimalist design pierce the dome's interior, connected by skybridges and magnetic levitation transport systems. Buildings are often integrated with the lunar terrain, with some structures built directly into craters or lava tubes.
# *   **Biomes and Green Spaces:** Despite the arid lunar surface, Luna City boasts meticulously designed biomes within the dome. Lush botanical gardens, artificial forests, and even simulated aquatic environments provide essential oxygen, food, and much-needed psychological respite.
#
# ## Society and Governance:
#
# *   **A Melting Pot of Humanity:** Luna City is a global hub, attracting individuals from every nation on Earth. It's a place where cultural diversity thrives, fostering a unique blend of traditions and perspectives.
# *   **The Lunar Council:** Governance is likely handled by a representative body, the Lunar Council, composed of delegates from various sectors and potentially even from different Earth nations. Decisions would focus on resource management, inter-colony relations, and the long-term sustainability of lunar life.
# *   **Meritocracy and Specialization:** Due to the demanding nature of lunar living, society likely emphasizes meritocracy and specialized skills. Engineers, scientists, miners, agriculturalists, and skilled technicians would be highly valued.
# *   **Unique Lunar Culture:** A distinct "Lunar" culture would emerge, shaped by the shared experience of living off-world. This might include new forms of art, music, philosophy, and even unique social customs adapted to the low-gravity environment.
#
# ## Economy and Industry:
#
# *   **Resource Extraction:** The Moon's abundant Helium-3, crucial for future fusion power, is a primary driver of Luna City's economy. Extensive mining operations extract this valuable resource.
# *   **Scientific Research Hub:** Luna City is a premier destination for scientific research. Observatories studying the universe from an unparalleled vantage point, laboratories investigating lunar geology, and research into advanced life support systems are vital.
# *   **Advanced Manufacturing:** The low gravity and vacuum of space are ideal for certain manufacturing processes, such as creating ultra-pure materials and complex alloys.
# *   **Interplanetary Trade:** Luna City would likely be a key node in an emerging interplanetary trade network, exporting lunar resources and manufactured goods to Earth and potentially other nascent space colonies.
# *   **Tourism:** The allure of visiting the Moon would make tourism a significant industry, with luxury habitats and unique experiences catering to Earth-bound visitors.
#
# ## Daily Life and Technology:
#
# *   **Low-Gravity Living:** Life in Luna City is intrinsically shaped by the Moon's one-sixth gravity. This influences everything from architecture and transportation to sports and everyday activities. People would be taller, stronger, and possess a unique gait.
# *   **Advanced Life Support:** Sophisticated closed-loop life support systems are paramount, recycling air, water, and waste with extreme efficiency.
# *   **Artificial Gravity Zones:** While much of the city might embrace low gravity, certain areas, like specialized hospitals or heavy industrial zones, could incorporate artificial gravity to mimic Earth's conditions.
# *   **Ubiquitous Connectivity:** Advanced communication networks would link every individual and facility, facilitating seamless interaction and access to information.
# *   **Robotics and Automation:** Robots and AI would play a crucial role in hazardous tasks, resource management, and maintaining the city's infrastructure.
# *   **Personalized Environments:** Advanced environmental controls would allow individuals to customize their living and working spaces, from temperature and humidity to simulated natural light.
#
# ## Challenges and Considerations:
#
# *   **Psychological Impact:** The isolation from Earth, the constant awareness of being in a hostile environment, and the limited living space could pose psychological challenges for residents.
# *   **Resource Scarcity:** While Helium-3 is abundant, other resources like water and organic materials would need to be meticulously managed and, where possible, synthesized.
# *   **Technological Dependence:** The entire existence of Luna City relies on the continuous functioning of complex and sophisticated technologies. Any failure could have catastrophic consequences.
# *   **Ethical and Political Questions:** The establishment of a lunar capital would inevitably raise complex ethical and political questions regarding sovereignty, resource ownership, and the rights of lunar citizens.
# *   **Defense and Security:** While peaceful, Luna City would need robust defense systems to protect against potential threats, whether from natural phenomena or other entities.
#
# ## Potential Landmarks and Attractions:
#
# *   **The Earthrise Observatory:** A state-of-the-art observatory offering unparalleled views of Earth and its phases.
# *   **The Tranquility Gardens:** Vast, bio-domed parks showcasing diverse flora and fauna, a welcome splash of green in the lunar landscape.
# *   **The Helium-3 Processing Hub:** A fascinating, albeit industrial, tour showcasing the extraction and refinement of this vital resource.
# *   **The Lunar Heritage Museum:** Chronicling humanity's journey to the Moon and the development of Luna City.
# *   **The Low-G Arena:** A venue for spectacular sporting events and performances adapted to the unique gravity.
# *   **The Crater Market:** A bustling marketplace where goods from across the solar system are traded.
#
# Luna City, as the capital of the Moon, represents a bold leap for humanity, a symbol of our ambition to not just visit but to inhabit the cosmos. It's a place where science fiction meets reality, a beacon of hope and progress in the silent, awe-inspiring vacuum of space.

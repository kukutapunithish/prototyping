# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

# response = model.invoke("What's the capital of the Moon?")
# print(response.content)

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

agent = create_agent(model=model)

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# That's a fun question! The Moon doesn't have a capital city like countries on Earth do. It's a natural celestial body, not a political entity.
#
# However, if we were to imagine a "capital" in a more symbolic sense, some might point to **Tranquility Base** as a significant location. This is where the Apollo 11 mission landed in 1969, marking humanity's first steps on the Moon. It's a historic and iconic spot.
#
# But to be clear, there's no official or recognized capital of the Moon.

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# The capital of the Moon, a city that hums with the low thrum of recycled air and the gentle whisper of magnetic levitation, is **Selene Prime**.
#
# It's not a city carved into the lunar regolith, though many of its foundational structures are. Selene Prime is a testament to humanity's audacious ambition, a sprawling metropolis that blossoms from the shadowed craters and glitters under the perpetual starlight.
#
# Imagine this:
#
# *   **The Lumina Spires:** Towering, crystalline structures that pierce the inky blackness of the lunar sky. They are not built of metal or concrete, but of bio-engineered, light-reactive polymers that absorb solar radiation during the lunar day and emit a soft, diffused glow during the long nights, bathing the city in an ethereal luminescence. These spires house the administrative centers, the Lunar Parliament, and the prestigious Academies of Stellar Sciences.
#
# *   **The Mare Sediments District:** Nestled within a vast, ancient lava plain, this is the oldest and most established part of Selene Prime. Here, the architecture is more robust, a fusion of reinforced basalt and self-healing alloys. This district is the heart of industry, housing the vast hydroponic farms that feed the city, the atmospheric processors, and the heavy manufacturing hubs that churn out the components for interstellar vessels. The echoing clang of automated foundries is a constant, though muffled, presence here.
#
# *   **The Crater Gardens:** These are not mere parks, but vast, enclosed biomes within artificially expanded craters. Imagine lush, alien flora, bio-luminescent fungi casting soft, shifting patterns of light, and tranquil waterfalls cascading down sculpted rock faces. These gardens are the lungs of Selene Prime, meticulously maintained by autonomous botanical drones, and serve as recreational havens for its citizens.
#
# *   **The Nexus Transit System:** Selene Prime is connected by a silent, efficient network of mag-lev tubes that crisscross the city, both above and below the surface. These tubes, shimmering with internal light, transport citizens at incredible speeds, their journeys offering panoramic views of the lunar landscape and the distant, blue marble of Earth.
#
# *   **The Great Observatory of Tycho:** Perched on the rim of the colossal Tycho crater, this is the city's scientific beacon. Its massive, adaptive lenses peer into the deepest reaches of the cosmos, a constant reminder of humanity's outward gaze. From its observation decks, one can witness nebulae bloom and galaxies spin, a humbling and inspiring spectacle.
#
# *   **The Lunar Senate Dome:** A majestic, transparent dome that hovers just above the surface in the central plaza. Within, the elected representatives of the Lunar Republic debate policy, their voices amplified and translated for the citizens gathered below, watching on massive holographic displays. The Earth hangs like a jewel in the sky above, a constant, silent observer.
#
# Selene Prime is a city of contrasts: the stark, silent beauty of the lunar surface juxtaposed with the vibrant, bustling life within its protective domes and spires. It is a city built on ingenuity, resilience, and an unyielding dream of a future among the stars. It is the beating heart of humanity's new frontier, a testament to what can be achieved when ambition meets the infinite canvas of space.

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Scifi Writer: Selenopolis

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Name: Selenopolis
#
# Location: A vast, geothermally heated cavern system deep beneath the Mare Imbrium.
#
# Vibe: Subterranean, Luminescent, Industrial
#
# Economy: Helium-3 extraction, Lunar regolith refinement, Zero-G manufacturing, Tourism (underground resorts and observatories)

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model=model,
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]
# Out:
# CapitalInfo(name='Luna Prime', location='Mare Imbrium, The Moon', vibe='Serene, technologically advanced, with a focus on scientific research and lunar resource management.', economy='Lunar mining (helium-3, rare earth elements), advanced robotics, zero-gravity manufacturing, and deep space tourism.')

# %%
response["structured_response"].name
# Out:
# 'Luna Prime'

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
# Out:
# Luna Prime is a city located at Mare Imbrium, The Moon

# %% [markdown]
# ## Without web search

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

# %%
from langchain.agents import create_agent

agent = create_agent(
    model=model
)
# Out:
# C:\Users\nithishkumar\Personal Data\Projects\overall\prototyping\ai_learn\agents\lca-lc-foundations\.venv\Lib\site-packages\langgraph\checkpoint\serde\encrypted.py:5: LangChainPendingDeprecationWarning: The default value of `allowed_objects` will change in a future version. Pass an explicit value (e.g., allowed_objects='messages' or allowed_objects='core') to suppress this warning.
#   from langgraph.checkpoint.serde.jsonplus import JsonPlusSerializer

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="How up to date is your training knowledge?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
print(response['messages'][-1].content)
# Out:
# My knowledge cutoff is **June 2024**. Therefore, I cannot provide you with any information about events or developments that have occurred since that time.

# %% [markdown]
# ## Add web search tool

# %%
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

web_search.invoke("Tell me about Fable5")
# Out:
# {'query': 'Tell me about Fable5',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://www.nbcnews.com/tech/security/fable-5-anthropic-release-public-mythos-claude-model-rcna349104',
#    'title': 'Anthropic releases Fable 5, the first public Mythos-class model',
#    'content': 'Anthropic released its latest model Tuesday afternoon, heralding the public’s first access to the AI company’s most powerful class of AI systems. The company says the model, termed Fable 5, is the first publicly available product in the same family as Anthropic’s powerful Mythos models, which sent [shock waves through the cybersecurity world](https://www.nbcnews.com/tech/security/anthropic-claude-mythos-ai-hackers-cybersecurity-vulnerabilities-rcna273673) earlier this year for their superhuman ability to find and exploit cyber vulnerabilities. The company had [made Mythos Preview available to over 150 organizations](https://www.anthropic.com/research/glasswing-initial-update) around the world to help financial institutions, software companies and healthcare networks shore up weaknesses in their cyber defenses prior to a wider public release of a Mythos-class model. Anthropic said Mythos 5 is the company’s “first model to consistently produce novel, compelling scientific hypotheses.”. [President Donald Trump signed an executive order](https://www.nbcnews.com/tech/tech-news/trump-ai-executive-order-rcna348072) last week that aims to establish a voluntary mechanism for AI companies to share their systems with the government for safety testing before they are publicly released and to shore up the government’s own cyberdefenses.',
#    'score': 0.6780931,
#    'raw_content': None},
#   {'url': 'https://www.forbes.com/sites/johnwerner/2026/06/15/4-things-you-should-know-about-fable-5',
#    'title': '4 Things You Should Know About Fable 5',
#    'content': 'Sign Up For NewslettersGamesShare a News Tip. *   Making It Their Way: Six TikTok Creators On Finding A High-Quality Content Strategy That Pays Off| Paid Program. *   The Hidden Tax On Enterprise AI: 1 In 5 Workers Lose A Full Day Every Week| Paid Program. *   The Enterprise AI Shortcut: Why Co-Innovation Is Setting A New Speed For Adopting and Operationalizing AI| Paid Program. *   New Era, New Icons: The Creators Redefining High-Quality Storytelling on TikTok| Paid Program. *   AI’s Nuanced Impact And A Quest To Quantify It. *   CMO Unscripted: Vulnerability Is The New Superpower For Leaders In The AI Era. *   Making It Their Way: Six TikTok Creators On Finding A High-Quality Content Strategy That Pays Off. Our best stories, exclusive reporting and Forbes perspectives on the day’s top news. Create your free account to receive personalized offers to your inbox, save articles and follow authors to get their latest stories in a weekly email roundup just for you!',
#    'score': 0.4757764,
#    'raw_content': None},
#   {'url': 'https://www.youtube.com/watch?v=KwQXyyVl2cM',
#    'title': 'Is Claude Fable 5 Worth the Hype? (Technical Deep Dive)',
#    'content': 'Is Claude Fable 5 Worth the Hype? (Technical Deep Dive)\nPrompt Engineering\n243000 subscribers\n251 likes\n11522 views\n9 Jun 2026\nAnthropic just released Fable 5 and Mythos 5, a new class of models that marks a seismic shift in AI. In this video, we dive into the Frontier Code Benchmarks, new safety classifiers, and why this represents the start of the \'Responsibility Era\' for LLMs.\n\nhttps://www.anthropic.com/news/claude-fable-5-mythos-5\nhttps://x.com/cursor_ai/status/2064394824313376787/photo/1\nhttps://developers.openai.com/api/docs/pricing\nhttps://www-cdn.anthropic.com/d00db56fa754a1b115b6dd7cb2e3c342ee809620.pdf\n\nMy voice to text App: whryte.com\nWebsite: https://engineerprompt.ai/\nRAG Beyond Basics Course:\nhttps://prompt-s-site.thinkific.com/courses/rag\nSignup for Newsletter, localgpt:\nhttps://tally.so/r/3y9bb0\n\nLet\'s Connect: \n🦾 Discord: https://discord.com/invite/t4eYQRUcXB\n☕ Buy me a Coffee: https://ko-fi.com/promptengineering\n|🔴 Patreon: https://www.patreon.com/PromptEngineering\n💼Consulting: https://calendly.com/engineerprompt/consulting-call\n📧 Business Contact: engineerprompt@gmail.com\nBecome Member: http://tinyurl.com/y5h28s6h\n\n💻 Pre-configured localGPT VM: https://bit.ly/localGPT (use Code: PromptEngineering for 50% off).  \n\nSignup for Newsletter, localgpt:\nhttps://tally.so/r/3y9bb0\n\n0:00 Fable 5 & Mythos 5: The New Paradigm\n1:14 Frontier Code Benchmark: 100% Improvement?\n3:02 Scaling Reasoning: Test Time Compute & Cost\n5:23 Safety Classifiers: Why Fable 5 Routes to Opus\n6:42 Pricing Deep Dive: Fable 5 vs The Market\n9:45 New Data Retention Policies Explained\n11:12 Subscription Changes: The End of the "Free Lunch"\n12:24 The "Third Era" of AI: Autonomous Loops\n\n\n#ClaudeFable #anthropic #mythos\n29 comments\n',
#    'score': 0.444493,
#    'raw_content': None},
#   {'url': 'https://medium.com/jonathans-musings/a-short-review-of-anthropics-fable-5-41b33952afb1',
#    'title': "A Short Review of Anthropic's Fable 5 | by Jonathan Fulton - Medium",
#    'content': "If you haven't heard, Anthropic recently had to shut off access to Fable 5 following a US government directive.",
#    'score': 0.40098447,
#    'raw_content': None},
#   {'url': 'https://platform.claude.com/docs/en/about-claude/models/introducing-claude-fable-5-and-claude-mythos-5',
#    'title': 'Introducing Claude Fable 5 and Claude Mythos 5 - Claude API Docs',
#    'content': '[Refusals, fallback, and billing on Claude Fable 5](https://platform.claude.com/docs/en/about-claude/models/introducing-claude-fable-5-and-claude-mythos-5#refusals-fallback-and-billing-on-claude-fable-5) summarizes all three. [Adaptive thinking](https://platform.claude.com/docs/en/build-with-claude/adaptive-thinking) is the only thinking mode on Claude Fable 5 and Claude Mythos 5. See [thinking output on Claude Fable 5 and Claude Mythos 5](https://platform.claude.com/docs/en/build-with-claude/adaptive-thinking#thinking-output-on-claude-fable-5-and-claude-mythos-5) for cross-model handling. [\ue010 Migration guide Step-by-step upgrade instructions from Claude Opus 4.8 and Claude Mythos Preview.](https://platform.claude.com/docs/en/about-claude/models/migration-guide)[\ue0d6 Models overview Specs and comparison for all current Claude models.](https://platform.claude.com/docs/en/about-claude/models/overview)[Adaptive thinking The only thinking mode on Claude Fable 5 and Claude Mythos 5.](https://platform.claude.com/docs/en/build-with-claude/adaptive-thinking)[Refusals and fallback How Claude Fable 5 declines requests, and how to retry on another model.](https://platform.claude.com/docs/en/build-with-claude/refusals-and-fallback)[Fallback credit Avoid paying the prompt-cache cost twice on a retry.](https://platform.claude.com/docs/en/build-with-claude/fallback-credit)[Fallback and billing cookbook \ue015 A worked end-to-end example of refusal handling, fallback, and billing.](https://platform.claude.com/cookbook/fable-5-fallback-billing-guide)[Effort Control thinking depth and cost on Claude Fable 5 and Claude Mythos 5.](https://platform.claude.com/docs/en/build-with-claude/effort)[Prompting Claude Fable 5 Fable-specific prompting techniques.](https://platform.claude.com/docs/en/build-with-claude/prompt-engineering/prompting-claude-fable-5). *   [Models](https://platform.claude.com/docs/en/about-claude/models/introducing-claude-fable-5-and-claude-mythos-5#models). *   [Refusals, fallback, and billing on Claude Fable 5](https://platform.claude.com/docs/en/about-claude/models/introducing-claude-fable-5-and-claude-mythos-5#refusals-fallback-and-billing-on-claude-fable-5). *   [Refusals](https://platform.claude.com/docs/en/about-claude/models/introducing-claude-fable-5-and-claude-mythos-5#refusals). *   [Fallback](https://platform.claude.com/docs/en/about-claude/models/introducing-claude-fable-5-and-claude-mythos-5#fallback). *   [Billing](https://platform.claude.com/docs/en/about-claude/models/introducing-claude-fable-5-and-claude-mythos-5#billing). *   [Availability](https://platform.claude.com/docs/en/about-claude/models/introducing-claude-fable-5-and-claude-mythos-5#availability). *   [Prompting](https://platform.claude.com/docs/en/about-claude/models/introducing-claude-fable-5-and-claude-mythos-5#prompting). *   [Messages API on Claude Fable 5 and Claude Mythos 5](https://platform.claude.com/docs/en/about-claude/models/introducing-claude-fable-5-and-claude-mythos-5#messages-api-on-claude-fable-5-and-claude-mythos-5). *   [Adaptive thinking is always on](https://platform.claude.com/docs/en/about-claude/models/introducing-claude-fable-5-and-claude-mythos-5#adaptive-thinking-is-always-on). *   [Raw thinking content is never returned](https://platform.claude.com/docs/en/about-claude/models/introducing-claude-fable-5-and-claude-mythos-5#raw-thinking-content-is-never-returned). *   [Supported features](https://platform.claude.com/docs/en/about-claude/models/introducing-claude-fable-5-and-claude-mythos-5#supported-features). *   [Migrating from earlier models](https://platform.claude.com/docs/en/about-claude/models/introducing-claude-fable-5-and-claude-mythos-5#migrating-from-earlier-models). *   [Next steps](https://platform.claude.com/docs/en/about-claude/models/introducing-claude-fable-5-and-claude-mythos-5#next-steps).',
#    'score': 0.3934788,
#    'raw_content': None}],
#  'response_time': 0.9,
#  'request_id': 'c57dc813-4c82-4a52-b947-0e6824edc844'}

# %%
agent = create_agent(
    model=model,
    tools=[web_search]
)

question = HumanMessage(content="Tell me about Fable5")

response = agent.invoke(
    {"messages": [question]}
)

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content='Tell me about Fable5', additional_kwargs={}, response_metadata={}, id='8c85c226-0bd6-4891-901d-6e74e61f6faa'),
#  AIMessage(content='', additional_kwargs={'function_call': {'name': 'web_search', 'arguments': '{"query": "Fable5"}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ed9b5-7e19-7313-805d-7dc94f73d733-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'Fable5'}, 'id': '0d36165e-b3eb-4a6f-8106-a772800f1391', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 44, 'output_tokens': 17, 'total_tokens': 61, 'input_token_details': {'cache_read': 0}}),
#  ToolMessage(content='{"query": "Fable5", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.youtube.com/shorts/hBsgJ61kY1k", "title": "What Is Fable 5? - YouTube", "content": "Mythos is FINALLY here but not really? We\'ve gotten Fable 5, a Mythos class model with TONS of features so lets break them all down.", "score": 0.5962692, "raw_content": null}, {"url": "https://www.xbox.com/en-US/games/fable", "title": "Fable: Available February 23, 2027 on XBOX and with Game Pass", "content": "[Join Game Pass](https://www.xbox.com/en-US/xbox-game-pass?xr=shellnav) [Browse Games](https://www.xbox.com/en-US/xbox-game-pass/games?xr=shellnav) [Deals with Game Pass](https://www.xbox.com/en-us/xbox-game-pass/deals?xr=shellnav) [XBOX Cloud Gaming](https://www.xbox.com/en-US/cloud-gaming?xr=shellnav)   [Games home](https://www.xbox.com/en-us/games?xr=shellnav) [Shop all console games](https://www.xbox.com/en-us/games/all-games/console?PlayWith=XboxSeriesX%7CS%2CXboxOne&xr=shellnav) [Shop all PC games](https://www.xbox.com/en-us/games/all-games/pc?PlayWith=PC&xr=shellnav) [Cloud games](https://www.xbox.com/en-us/play?xr=shellnav) [XBOX Play Anywhere](https://www.xbox.com/en-us/games/xbox-play-anywhere?xr=shellnav) [Free-to-Play games](https://www.xbox.com/en-us/games/free-to-play?xr=shellnav) [Optimized for XBOX Series X|S](https://www.xbox.com/en-us/games/optimized?xr=shellnav) [Optimized for handhelds](https://www.xbox.com/en-us/handhelds/handheld-compatibility?xr=shellnav) [Backward compatible games](https://www.xbox.com/en-us/games/backward-compatibility?xr=shellnav) [Sales & Specials](https://www.xbox.com/en-us/promotions/sales/sales-and-specials?xr=shellnav) [Redeem Code](https://www.xbox.com/en-us/redeem?xr=shellnav)   [Explore all devices](https://www.xbox.com/en-us/devices?xr=shellnav)  [Meet XBOX Series X|S](https://www.xbox.com/en-us/consoles?xr=shellnav) [XBOX Series X](https://www.xbox.com/en-us/consoles/xbox-series-x?xr=shellnav) [XBOX Series S](https://www.xbox.com/en-us/consoles/xbox-series-s?xr=shellnav) [Shop all consoles](https://www.xbox.com/en-us/consoles/all-consoles?xr=shellnav) [Compare consoles](https://www.xbox.com/en-us/consoles/compare?xr=shellnav) [Help me choose a console](https://www.xbox.com/en-us/consoles/help-me-choose?xr=shellnav) [Where to buy](https://www.xbox.com/en-us/where-to-buy?xr=shellnav)   [Shop all accessories](https://www.xbox.com/en-us/accessories?xr=shellnav) [Controllers](https://www.xbox.com/en-us/accessories?xr=shellnav#controllers) [Design your controller](https://xboxdesignlab.xbox.com/?xr=shellnav&OCID=XboxSite_UHFDevAcc_DesignYourController) [Headsets](https://www.xbox.com/en-us/accessories?xr=shellnav#headsets) [Hard drives & storage](https://www.xbox.com/en-us/accessories?xr=shellnav#storage) [Mobile gaming accessories](https://www.xbox.com/en-us/accessories?xr=shellnav#mobile) [Where to buy](https://www.xbox.com/en-us/where-to-buy?xr=shellnav#accessories)  [XBOX on PC](https://www.xbox.com/en-us/xbox-on-pc?xr=shellnav) [XBOX on handhelds](https://www.xbox.com/en-us/xbox-on-handhelds?xr=shellnav) [XBOX on mobile](https://www.xbox.com/en-us/xbox-on-mobile?xr=shellnav) [XBOX on TVs](https://www.xbox.com/en-us/xbox-on-tvs?xr=shellnav) [XBOX on VR headsets](https://www.xbox.com/en-us/xbox-on-vr-headsets?xr=shellnav)  [Play](https://www.xbox.com/en-US/play?xr=shellnav)  [Shop Games](https://www.xbox.com/en-us/games?xr=shellnav) [Shop Game Pass](https://www.xbox.com/en-us/xbox-game-pass?xr=shellnav) [Shop Consoles](https://www.xbox.com/en-us/consoles/all-consoles?xr=shellnav) [Shop Accessories](https://www.xbox.com/en-us/accessories?xr=shellnav) [Shop Deals](https://www.xbox.com/en-us/promotions/sales/sales-and-specials?xr=shellnav)    [XBOX community](https://www.xbox.com/en-US/community?xr=shellnav) [FanFest](https://www.xbox.com/en-us/community/fanfest?xr=shellnav) [XBOX News](https://news.xbox.com/en-us/?xr=shellnav) [Sustainability](https://www.xb ...
#  AIMessage(content='The search results indicate that "Fable 5" is not a video game. Instead, it appears to be a reference to a powerful AI model, possibly from Anthropic (mentioned in relation to Claude). There are several YouTube videos and a Reddit post discussing "Fable 5" in the context of AI capabilities, such as building research pipelines, coding, and simulations. Some results suggest that access to "Fable 5" has been restricted or banned by the US government.\n\nIt\'s important to note that the Fable video game series exists, but "Fable 5" is not part of it. The next installment in the Fable game series is simply titled "Fable" and is scheduled for release on February 23, 2027.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ed9b5-87f8-79e1-9fe7-f817fd4c6d5d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 4719, 'output_tokens': 160, 'total_tokens': 4879, 'input_token_details': {'cache_read': 0}})]

# %% [markdown]
# trace: https://smith.langchain.com/public/59432173-0dd6-49e8-9964-b16be6048426/r

# %%
res = response['messages'].copy()

# %%
res[3]
# Out:
# AIMessage(content='The search results indicate that "Fable 5" is not a video game. Instead, it appears to be a reference to a powerful AI model, possibly from Anthropic (mentioned in relation to Claude). There are several YouTube videos and a Reddit post discussing "Fable 5" in the context of AI capabilities, such as building research pipelines, coding, and simulations. Some results suggest that access to "Fable 5" has been restricted or banned by the US government.\n\nIt\'s important to note that the Fable video game series exists, but "Fable 5" is not part of it. The next installment in the Fable game series is simply titled "Fable" and is scheduled for release on February 23, 2027.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ed9b5-87f8-79e1-9fe7-f817fd4c6d5d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 4719, 'output_tokens': 160, 'total_tokens': 4879, 'input_token_details': {'cache_read': 0}})

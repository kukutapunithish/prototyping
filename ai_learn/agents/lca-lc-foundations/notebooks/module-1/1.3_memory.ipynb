# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

# %% [markdown]
# ## No memory

# %%
from langchain.agents import create_agent


agent = create_agent(
   model
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is nithish and my favourite colour is green")

response = agent.invoke(
    {"messages": [question]} 
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is nithish and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='cb3caaf6-57a7-4f2d-a6d3-41a0f03547f0'),
#               AIMessage(content="Hello Nithish! It's nice to meet you. Green is a beautiful favorite color. What do you like about green?", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ed9d5-f20b-7090-8509-b0d3b5cf9c23-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 14, 'output_tokens': 27, 'total_tokens': 41, 'input_token_details': {'cache_read': 0}})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]} 
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='6d50af31-01bb-4ef3-9394-6179d58d2b8b'),
#               AIMessage(content='I cannot know your favorite color because I am a large language model, and I do not have access to your personal information. I have no way of knowing what you like or dislike.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ed9d6-1476-7be2-9005-764b2b8d95f8-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 8, 'output_tokens': 37, 'total_tokens': 45, 'input_token_details': {'cache_read': 0}})]}

# %% [markdown]
# ## Memory

# %%
from langgraph.checkpoint.memory import InMemorySaver  


agent = create_agent(
    model,
    checkpointer=InMemorySaver(),  
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is nithish and my favourite colour is green")
config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [question]},
    config,  
)

# %%
pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is nithish and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='38db130c-5b45-4e17-9f04-3fd4798c5788'),
#               AIMessage(content="Hello Nithish! It's lovely to meet you. Green is a fantastic favorite color. It's often associated with nature, growth, harmony, and freshness.\n\nWhat do you like most about the color green? Or perhaps you have a favorite shade of green?", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ed9d7-9d06-76a2-9365-bc5b96df7b29-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 14, 'output_tokens': 56, 'total_tokens': 70, 'input_token_details': {'cache_read': 0}})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]},
    config,  
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is nithish and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='38db130c-5b45-4e17-9f04-3fd4798c5788'),
#               AIMessage(content="Hello Nithish! It's lovely to meet you. Green is a fantastic favorite color. It's often associated with nature, growth, harmony, and freshness.\n\nWhat do you like most about the color green? Or perhaps you have a favorite shade of green?", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ed9d7-9d06-76a2-9365-bc5b96df7b29-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 14, 'output_tokens': 56, 'total_tokens': 70, 'input_token_details': {'cache_read': 0}}),
#               HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='9ed45e1e-d917-441c-b92a-97e5d1414360'),
#               AIMessage(content='You just told me! Your favorite color is **green**. 😊', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ed9d7-abe4-7813-8099-f7e9e3732a1b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 79, 'output_tokens': 13, 'total_tokens': 92, 'input_token_details': {'cache_read': 0}})]}

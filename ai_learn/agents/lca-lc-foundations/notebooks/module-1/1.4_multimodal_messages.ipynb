# %% [markdown]
# ## Text input

# %% [markdown]
# https://platform.openai.com/docs/models

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

# %%
from langchain.agents import create_agent

agent = create_agent(
    model=model,
    system_prompt="You are a science fiction writer, answer based on user request",
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content=[
    {"type": "text", "text": "What is the capital of The Moon?"}
])

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# The capital of The Moon is **Selenopolis**.
#
# It's not just a city; it's a testament to humanity's audacious leap from the cradle of Earth to the silent, silver embrace of our celestial neighbor. Selenopolis isn't built *on* the Moon, not entirely. It's a sprawling, crystalline marvel that blossoms *from* it.
#
# Imagine this:
#
# **Location:** Selenopolis is nestled within a colossal, ancient impact crater, likely one of the larger mare basins. The crater's rim provides a natural shield against micrometeoroids and the harsh solar radiation, while the interior offers a more stable, geologically interesting foundation. The city's main arteries and residential sectors are carved deep into the regolith and bedrock, forming vast, interconnected caverns and tunnels. Above ground, only the most vital structures and transport hubs break the lunar surface.
#
# **Architecture:** The dominant aesthetic is one of organic, crystalline growth. Structures aren't constructed in the traditional sense; they are *grown*. Using advanced bio-mineralization techniques and lunar ice as a base, architects and bio-engineers cultivate buildings that resemble enormous, luminescent geodes. These structures shimmer with an internal light, their facets catching and refracting the Earthlight and starlight in breathtaking displays. Think of colossal, translucent quartz formations, laced with veins of glowing, engineered minerals that provide power and atmospheric regulation.
#
# *   **The Lumina Spires:** These are the tallest above-ground structures, reaching hundreds of meters into the vacuum. They aren't just decorative; they are atmospheric processors, solar energy collectors, and communication hubs, their tips piercing the thin, artificial atmosphere carefully maintained within the crater.
# *   **The Geode Domes:** These are the primary residential and civic areas. Massive, semi-transparent domes, grown from reinforced lunar silica, allow inhabitants to gaze upon the stark beauty of the lunar landscape and the breathtaking spectacle of Earth hanging in the black sky. Inside, the atmosphere is carefully managed, with simulated daylight cycles and carefully curated flora.
# *   **The Subterranean Nexus:** This is the heart of Selenopolis. Deep beneath the surface, a network of vast caverns houses the city's life support systems, advanced research facilities, manufacturing hubs, and the government centers. The walls of these caverns are often lined with glowing, bioluminescent fungi and mineral deposits, creating an otherworldly, yet functional, environment.
#
# **Atmosphere:** Selenopolis breathes. A carefully controlled, thin but breathable atmosphere is maintained within the crater walls and the Geode Domes. It's not Earth-like; it's lighter, with a unique mineral tang, a constant reminder of its artificiality and the preciousness of every breath. The air is recycled with extreme efficiency, and the scent of cultivated lunar flora, adapted to low gravity and mineral-rich soil, occasionally drifts through the public spaces.
#
# **Transportation:** Gravity is a constant consideration.
# *   **Mag-Lev Tubes:** Sleek, silent mag-lev trains glide through pressurized tubes, connecting the various sectors of the city, both above and below ground.
# *   **Personal Grav-Chutes:** For shorter distances and within the lower gravity environments, personal grav-chutes and assisted locomotion devices are common. Think of gliding rather than walking.
# *   **Lunar Rovers and Exosuits:** For excursions outside the city's protective embrace, advanced, pressurized rovers and specialized exosuits are the norm.
#
# **Culture and Society:** Life in Selenopolis is a blend of scientific rigor, artistic expression, and a profound sense of community.
# *   **Earth-Gazing:** The constant presence of Earth in the sky is a powerful cultural touchstone. There are designated "Earth-Gazing Parks" where citizens gather to contemplate their home world, and holographic projections of Earth's changing weather patterns are projected onto the interiors of the Geode Domes.
# *   **Lunar Arts:** The unique environment has inspired new forms of art. Sculptures carved from moon rock, light-and-shadow performances within the crystal structures, and music designed to resonate with the low gravity are popular.
# *   **The Selenian Identity:** A distinct identity has emerged – the "Selenians." They are often characterized by their calm demeanor, their meticulous attention to detail, and a deep appreciation for the fragility and resilience of life. They are the inheritors of a grand experiment, and the custodians of humanity's future beyond Earth.
#
# **Government:** The capital is home to the **Lunar Concordance**, a council comprised of elected representatives from across the Moon's various settlements and orbital stations. Decisions are made with a long-term perspective, prioritizing sustainability, scientific advancement, and the continued exploration of the cosmos.
#
# Selenopolis is more than just a capital; it's a beacon, a symbol of what humanity can achieve when it dares to dream beyond the horizon, and to build its future among the stars. It's a city that whispers of the silence of space, yet hums with the vibrant pulse of life.

# %% [markdown]
# ## Image input

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept='.png', multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.png', description='Upload')

# %%
print(uploader.value)
# Out:
# ({'name': 'Gemini_Generated_Image_4an9ys4an9ys4an9.png', 'type': 'image/png', 'size': 2251571, 'content': <memory at 0x00000175FFEBE140>, 'last_modified': datetime.datetime(2026, 3, 26, 16, 50, 1, 828000, tzinfo=datetime.timezone.utc)},)

# %%
import base64

# Get the first (and only) uploaded file dict
uploaded_file = uploader.value[0]

# This is a memoryview
content_mv = uploaded_file["content"]

# Convert memoryview -> bytes
img_bytes = bytes(content_mv)  # or content_mv.tobytes()

# Now base64 encode
img_b64 = base64.b64encode(img_bytes).decode("utf-8")

# %%
multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this image"},
    {"type": "image", "base64": img_b64, "mime_type": "image/png"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# The image depicts a young man, likely a programmer or developer, engrossed in his work late at night. He's seated at a desk, illuminated by the glow of his laptop and a large monitor displaying lines of code. A mug of coffee rests beside him, a common companion for those burning the midnight oil.
#
# The background suggests a cozy, albeit somewhat cluttered, workspace. Bookshelves filled with titles are visible, hinting at a thirst for knowledge. A lamp casts a warm glow, and the starry night sky outside the window adds a serene, contemplative atmosphere.
#
# What elevates this scene from a typical late-night coding session to something more extraordinary are the wisps of luminous energy swirling around the man and his screens. These ethereal trails, shimmering with blues and yellows, seem to emanate from the code itself, suggesting that the man is not just writing programs, but perhaps weaving them into existence, or that the digital world he's building is gaining a life of its own. It's a subtle touch that hints at the magic and creativity inherent in coding, transforming the mundane act of typing into something almost mystical.

# %% [markdown]
# ## Audio input

# %%
import sounddevice as sd
from scipy.io.wavfile import write
import base64
import io
import time
from tqdm import tqdm

# Recording settings
duration = 5  # seconds
sample_rate = 44100

print("Recording...")
audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1)
# Progress bar for the duration
for _ in tqdm(range(duration * 10)):   # update 10× per second
    time.sleep(0.1)
sd.wait()
print("Done.")

# Write WAV to an in-memory buffer
buf = io.BytesIO()
write(buf, sample_rate, audio)
wav_bytes = buf.getvalue()

aud_b64 = base64.b64encode(wav_bytes).decode("utf-8")
# Out:
# Recording...
# 100%|████████████████████████████████████████████████████████████████████████████████| 50/50 [00:05<00:00,  9.74it/s]
# Done.

# %%
agent = create_agent(
    model=model,
)

multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this audio file"},
    {"type": "audio", "base64": aud_b64, "mime_type": "audio/wav"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# The audio file contains a question: **"What is the best way to cool in life?"**

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

# %%
from dataclasses import dataclass

@dataclass
class ColourContext:
    favourite_colour: str = "blue"
    least_favourite_colour: str = "yellow"

# %%
from langchain.agents import create_agent

agent = create_agent(
    model=model,
    context_schema=ColourContext  
)

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What is my favourite colour?")]},
    context=ColourContext()
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='What is my favourite colour?', additional_kwargs={}, response_metadata={}, id='d16e289a-6928-4de0-9155-427e969c4cbd'),
#               AIMessage(content='I do not have access to your personal information, so I cannot tell you what your favorite color is. I am a language model and do not have the ability to know your preferences or personal details.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019eda77-0e21-7c10-8399-377395585c45-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 7, 'output_tokens': 40, 'total_tokens': 47, 'input_token_details': {'cache_read': 0}})]}

# %% [markdown]
# ## Accessing Context

# %%
from langchain.tools import tool, ToolRuntime

@tool
def get_favourite_colour(runtime: ToolRuntime) -> str:
    """Get the favourite colour of the user"""
    return runtime.context.favourite_colour

@tool
def get_least_favourite_colour(runtime: ToolRuntime) -> str:
    """Get the least favourite colour of the user"""
    return runtime.context.least_favourite_colour

# %%
agent = create_agent(
    model=model,
    tools=[get_favourite_colour, get_least_favourite_colour],
    # context_schema=ColourContext
)

# %%
response = agent.invoke(
    {"messages": [HumanMessage(content="What is my favourite colour?")]},
    context=ColourContext()
)

pprint(response)
# Out:
# C:\Users\nithishkumar\Personal Data\Projects\overall\prototyping\ai_learn\agents\lca-lc-foundations\.venv\Lib\site-packages\pydantic\main.py:464: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `none` - serialized value may not be as expected [field_name='context', input_value=ColourContext(favourite_c...vourite_colour='yellow'), input_type=ColourContext])
#   return self.__pydantic_serializer__.to_python(
# {'messages': [HumanMessage(content='What is my favourite colour?', additional_kwargs={}, response_metadata={}, id='354884f4-b9f0-4791-aafc-33fa89fb30dd'),
#               AIMessage(content='', additional_kwargs={'function_call': {'name': 'get_favourite_colour', 'arguments': '{}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019eda77-3de1-7ee3-9969-84b81d048a73-0', tool_calls=[{'name': 'get_favourite_colour', 'args': {}, 'id': 'c66a02c7-ad7c-4678-a4d0-9ddaed21930a', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 72, 'output_tokens': 13, 'total_tokens': 85, 'input_token_details': {'cache_read': 0}}),
#               ToolMessage(content='blue', name='get_favourite_colour', id='a5b24b1e-5c4b-407c-975b-73be84926bab', tool_call_id='c66a02c7-ad7c-4678-a4d0-9ddaed21930a'),
#               AIMessage(content='', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019eda77-45ed-78f2-a27c-9b3ef399baff-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 103, 'output_tokens': 0, 'total_tokens': 103, 'input_token_details': {'cache_read': 0}})]}

# %%
response = agent.invoke(
    {"messages": [HumanMessage(content="What is my favourite colour?")]},
    context=ColourContext(favourite_colour="green")
)

pprint(response)
# Out:
# C:\Users\nithishkumar\Personal Data\Projects\overall\prototyping\ai_learn\agents\lca-lc-foundations\.venv\Lib\site-packages\pydantic\main.py:464: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `none` - serialized value may not be as expected [field_name='context', input_value=ColourContext(favourite_c...vourite_colour='yellow'), input_type=ColourContext])
#   return self.__pydantic_serializer__.to_python(
# {'messages': [HumanMessage(content='What is my favourite colour?', additional_kwargs={}, response_metadata={}, id='8b94d957-2f87-47e8-b5d8-0a90994ef9ee'),
#               AIMessage(content='', additional_kwargs={'function_call': {'name': 'get_favourite_colour', 'arguments': '{}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019eda77-4aa7-72f3-9ac8-cd092489df1e-0', tool_calls=[{'name': 'get_favourite_colour', 'args': {}, 'id': '0677ea1c-973f-4a3f-aea4-883e0fc30878', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 72, 'output_tokens': 13, 'total_tokens': 85, 'input_token_details': {'cache_read': 0}}),
#               ToolMessage(content='green', name='get_favourite_colour', id='29ddc36c-3eb4-4479-a342-2337246fe77a', tool_call_id='0677ea1c-973f-4a3f-aea4-883e0fc30878'),
#               AIMessage(content='', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019eda77-5be2-73f0-a33f-836b6bd8d615-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 103, 'output_tokens': 0, 'total_tokens': 103, 'input_token_details': {'cache_read': 0}})]}

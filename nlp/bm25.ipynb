# %% [markdown]
# Notes:
#
# 1. term frequency, idf (how rare is the term), Dl (Document length) these are three things which are foundational for the BM25
# 2. BM25 tries to answer a fundamental question which is "Given the query and document how relevant is the document?"
# 3. BM25 is a probabilistic score so it acts a ranking mechanism.
#
# formula:
# BM25 = sum IDF(t)*(f(t,D)*(k1 + 1))/(f(t,D) + k1(1 - b + b|D|/avgdl))
#
# Unknown's:
#
# 1. What is the good bm25 score vs bad?
# 2. Why is the name BM25 has 25 in it?

# %%
import bm25s

# %%
from sklearn.datasets import fetch_20newsgroups
newsgroups = fetch_20newsgroups(
    subset="train",
    categories=["sci.space", "comp.graphics", "rec.sport.baseball"],
    remove=("headers", "footers", "quotes")
)
documents = newsgroups.data[:1000]

# %%
corpus = documents.copy()

# [
#     "a cat is a feline and likes to purr",
#     "a dog is the human's best friend and loves to play",
#     "a bird is a beautiful animal that can fly",
#     "a fish is a creature that lives in water and swims",
# ]

# %%
retriver = bm25s.BM25(corpus=corpus)
retriver.index(bm25s.tokenize(corpus))

def query_corpus(query):
    results, scores = retriver.retrieve(bm25s.tokenize(query),k=2)

    doc, score = results[0,0],scores[0,0]

    for i, (doc, score) in enumerate(zip(results[0], scores[0])):
        print(f"Rank {i+1} (score: {score:.2f}): {doc}")
# Out:
# ...
# BM25S Compute Scores:   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
query = "whe is roket going to mooon?"
query_corpus(query)
# Out:
# ...
# BM25S Retrieve:   0%|          | 0/1 [00:00<?, ?it/s]
# Rank 1 (score: 1.86): Does anyone have the scoop on Scot Erickson?  How long is he going to be
# out for?
#
#
# Rank 2 (score: 1.82):
#
#
# 	They did the rollout already??!?  I am going to have to pay more
# attention to the news.  Are any of the gifs headed for wuarchive??
#
#
# Patrick

# %%
documents
# Out:
# ["\nBy '8 grey level images' you mean 8 items of 1bit images?\nIt does work(!), but it doesn't work if you have more than 1bit\nin your screen and if the screen intensity is non-linear.\n\nWith 2 bit per pixel; there could be 1*c_1 + 4*c_2 timing,\nthis gives 16 levels, but they are linear if screen intensity is\nlinear.\nWith 1*c_1 + 2*c_2 it works, but we have to find the best\ncompinations -- there's 10 levels, but 16 choises; best 10 must be\nchosen. Different compinations for the same level, varies a bit, but\nthe levels keeps their order.\n\nReaders should verify what I wrote... :-)",
# ...

# %% [markdown]
# BM25 is an algorithm that ranks the documents based on the relevance for the given query. unlike other algorithms it takes into account document length, importance of the word, frequency of the word which solves the problem of relevance. it is fast efficient and relevant accuracy. It failes when there are spelling mistakes which gives irrelevant results.
